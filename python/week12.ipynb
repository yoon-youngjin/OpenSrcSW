# %% [markdown]
# 실습 1

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f) # list형태로 return
next(data)
label = [''] * 3
mx = [0] * 3
for row in data:
    for i in range(3, 5):
        row[i] = float(row[i])
    
    if (row[4] - row[3]) > mx[0]:
        mx[0] = (row[4] - row[3])
        label[0] = row[0]
        
    if row[3] < mx[2]:
        mx[2] = row[3]
        label[1] = row[0]
    
    if row[4] > mx[1]:
        mx[1] = row[4]
        label[2] = row[0]
                       
f.close()
        
print('일교차가 가장 큰 날')
print(label[0])

print('일교차가 가장 큰 날')
print(label[1])

print('일교차가 가장 큰 날')
print(label[2])
# Out:
# 일교차가 가장 큰 날
# 2021-04-21
# 일교차가 가장 큰 날
# 2021-01-08
# 일교차가 가장 큰 날
# 2021-07-24

# %% [markdown]
# 실습 2

# %%
f = open('subwayfee.csv')
data = csv.reader(f) # list형태로 return
next(data)

line={}
for row in data:
    station={}
    station[row[3] + ' ' + row[1]] = int(row[4].replace(',',''))+int(row[5].replace(',',''))
    if row[1] in line:
        line[row[1]].update(station)
        
    else:
        line[row[1]] = station
        
for station in line:
    print('이용객이 가장 많은 역 순위')
    sorted_list = sorted(line[station].items(), key=lambda x:x[1], reverse=True)
    for i in range(3):
        print(str(i+1)+'. '+sorted_list[i][0]+'('+str(sorted_list[i][1])+'명)')
    print('이용객이 가장 적은 역 순위')
    for j in range(3):
        print(str(j+1)+'. '+sorted_list[-(j+1)][0]+'('+str(sorted_list[-(j+1)][1])+'명)')
    print()
# Out:
# 이용객이 가장 많은 역 순위
# dict_items([('서울역 1호선', 2016415), ('동묘앞 1호선', 231777), ('시청 1호선', 1008772), ('종각 1호선', 1496552), ('종로3가 1호선', 783001), ('종로5가 1호선', 722233), ('동대문 1호선', 390897), ('신설동 1호선', 516616), ('제기동 1호선', 426428), ('청량리(서울시립대입구) 1호선', 622014)])
# 1. 서울역 1호선(2016415명)
# 2. 종각 1호선(1496552명)
# 3. 시청 1호선(1008772명)
# 이용객이 가장 적은 역 순위
# 1. 동묘앞 1호선(231777명)
# 2. 동대문 1호선(390897명)
# 3. 제기동 1호선(426428명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('시청 2호선', 1050132), ('을지로입구 2호선', 1971517), ('을지로3가 2호선', 1013587), ('을지로4가 2호선', 510510), ('동대문역사문화공원(DDP) 2호선', 614502), ('신당 2호선', 597826), ('상왕십리 2호선', 634138), ('왕십리(성동구청) 2호선', 739774), ('한양대 2호선', 394076), ('뚝섬 2호선', 1088751), ('성수 2호선', 1795460), ('건대입구 2호선', 1856349), ('구의(광진구청) 2호선', 1076270), ('강변(동서울터미널) 2호선', 1464632), ('잠실나루 2호선', 579935), ('잠실(송파구청) 2호선', 3619485), ('잠실새내 2호선', 962983), ('종합운동장 2호선', 328570), ('삼성(무역센터) 2호선', 2645365), ('선릉 2호선', 2308247), ('역삼 2호선', 2434091), ('강남 2호선', 4074070), ('교대(법원.검찰청) 2호선', 1542954), ('서초 2호선', 973546), ('방배 2호선', 761162), ('사당 2호선', 1770878), ('낙성대(강감찬) 2호선', 1269826), ('서울대입구(관악구청) 2호선', 2254634), ('봉천 2호선', 980725), ('신림 2호선', 3020858), ('신대방 2호선', 1185952), ('구로디지털단지 2호선', 2842748), ('대림(구로구청) 2호선', 1099501), ('신도림 2호선', 2266910), ('문래 2호선', 988445), ('영등포구청 2호선', 1038110), ('당산 2호선', 936269), ('합정 2호선', 1649284), ('홍대입구 2호선', 3073490), ('신촌 2호선', 1602531), ('이대 2호선', 638188), ('아현 2호선', 425722), ('충정로(경기대입구) 2호선', 446356), ('용답 2호선', 119057), ('신답 2호선', 75281), ('신설동 2호선', 131950), ('도림천 2호선', 60023), ('양천구청 2호선', 286866), ('신정네거리 2호선', 433593), ('용두(동대문구청) 2호선', 88585)])
# 1. 강남 2호선(4074070명)
# 2. 잠실(송파구청) 2호선(3619485명)
# 3. 홍대입구 2호선(3073490명)
# 이용객이 가장 적은 역 순위
# 1. 도림천 2호선(60023명)
# 2. 신답 2호선(75281명)
# 3. 용두(동대문구청) 2호선(88585명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('지축 3호선', 189345), ('구파발 3호선', 888867), ('연신내 3호선', 1501139), ('불광 3호선', 666042), ('녹번 3호선', 653809), ('홍제 3호선', 662149), ('무악재 3호선', 157135), ('독립문 3호선', 259667), ('경복궁(정부서울청사) 3호선', 913142), ('안국 3호선', 935685), ('종로3가 3호선', 460517), ('을지로3가 3호선', 459693), ('충무로 3호선', 22), ('동대입구 3호선', 385720), ('약수 3호선', 548905), ('금호 3호선', 322978), ('옥수 3호선', 388710), ('압구정 3호선', 1577372), ('신사 3호선', 1584922), ('잠원 3호선', 201620), ('고속터미널 3호선', 2110764), ('교대(법원.검찰청) 3호선', 494232), ('남부터미널(예술의전당) 3호선', 1358816), ('양재(서초구청) 3호선', 1840733), ('매봉 3호선', 525961), ('도곡 3호선', 235113), ('대치 3호선', 446583), ('학여울 3호선', 86553), ('대청 3호선', 407796), ('일원 3호선', 398647), ('수서 3호선', 765948), ('가락시장 3호선', 340231), ('경찰병원 3호선', 307893), ('오금 3호선', 261903)])
# 1. 고속터미널 3호선(2110764명)
# 2. 양재(서초구청) 3호선(1840733명)
# 3. 신사 3호선(1584922명)
# 이용객이 가장 적은 역 순위
# 1. 충무로 3호선(22명)
# 2. 학여울 3호선(86553명)
# 3. 무악재 3호선(157135명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('수유(강북구청) 4호선', 1520960), ('미아(서울사이버대학) 4호선', 598109), ('미아사거리 4호선', 1183976), ('길음 4호선', 867740), ('성신여대입구(돈암) 4호선', 946432), ('한성대입구(삼선교) 4호선', 598827), ('혜화 4호선', 1586293), ('동대문 4호선', 761454), ('동대문역사문화공원(DDP) 4호선', 697139), ('충무로 4호선', 1141951), ('명동 4호선', 1120710), ('회현(남대문시장) 4호선', 1101325), ('서울역 4호선', 656261), ('숙대입구(갈월) 4호선', 595684), ('삼각지 4호선', 239312), ('신용산 4호선', 813006), ('이촌(국립중앙박물관) 4호선', 338193), ('동작(현충원) 4호선', 51740), ('총신대입구(이수) 4호선', 794943), ('사당 4호선', 1110379), ('남태령 4호선', 47323), ('당고개 4호선', 514990), ('상계 4호선', 786326), ('노원 4호선', 945131), ('창동 4호선', 1087141), ('쌍문 4호선', 1252103)])
# 1. 혜화 4호선(1586293명)
# 2. 수유(강북구청) 4호선(1520960명)
# 3. 쌍문 4호선(1252103명)
# 이용객이 가장 적은 역 순위
# 1. 남태령 4호선(47323명)
# 2. 동작(현충원) 4호선(51740명)
# 3. 삼각지 4호선(239312명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('서울역 경부선', 235833), ('남영 경부선', 432209), ('용산 경부선', 1832016), ('노량진 경부선', 405145), ('대방 경부선', 568655), ('영등포 경부선', 1871400), ('신도림 경부선', 170842), ('신길 경부선', 371308), ('구로 경부선', 853482), ('가산디지털단지 경부선', 906960), ('금천구청 경부선', 499432), ('석수 경부선', 412686), ('관악 경부선', 295894), ('안양 경부선', 1044528), ('명학 경부선', 394746), ('금정 경부선', 1232241), ('군포 경부선', 338530), ('의왕 경부선', 408145), ('성균관대 경부선', 673542), ('화서 경부선', 341850), ('수원 경부선', 1851035), ('독산 경부선', 847465), ('세류 경부선', 135438), ('병점 경부선', 691206), ('세마 경부선', 122661), ('오산대 경부선', 155179), ('오산 경부선', 477563), ('진위 경부선', 69788), ('송탄 경부선', 215403), ('서정리 경부선', 335291), ('평택지제 경부선', 171878), ('평택 경부선', 588720), ('성환 경부선', 171202), ('직산 경부선', 35020), ('두정 경부선', 264350), ('천안 경부선', 229016), ('당정 경부선', 266939), ('서동탄 경부선', 60198), ('광명 경부선', 160621)])
# 1. 영등포 경부선(1871400명)
# 2. 수원 경부선(1851035명)
# 3. 용산 경부선(1832016명)
# 이용객이 가장 적은 역 순위
# 1. 직산 경부선(35020명)
# 2. 서동탄 경부선(60198명)
# 3. 진위 경부선(69788명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('개봉 경인선', 885635), ('오류동 경인선', 476859), ('역곡 경인선', 1183956), ('부천 경인선', 1450853), ('송내 경인선', 1205731), ('부평 경인선', 1474919), ('백운 경인선', 277715), ('동암 경인선', 654063), ('주안 경인선', 843004), ('제물포 경인선', 453299), ('동인천 경인선', 547111), ('인천 경인선', 115305), ('구일 경인선', 294185), ('소사 경인선', 347674), ('부개 경인선', 342332), ('간석 경인선', 236484), ('도원 경인선', 110015), ('온수(성공회대입구) 경인선', 270919), ('중동 경인선', 369610), ('도화 경인선', 153284)])
# 1. 부평 경인선(1474919명)
# 2. 부천 경인선(1450853명)
# 3. 송내 경인선(1205731명)
# 이용객이 가장 적은 역 순위
# 1. 도원 경인선(110015명)
# 2. 인천 경인선(115305명)
# 3. 도화 경인선(153284명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('이촌(국립중앙박물관) 경원선', 132100), ('서빙고 경원선', 80080), ('한남 경원선', 163977), ('옥수 경원선', 2274), ('응봉 경원선', 64612), ('왕십리(성동구청) 경원선', 726662), ('청량리(서울시립대입구) 경원선', 647646), ('외대앞 경원선', 329211), ('신이문 경원선', 320630), ('석계 경원선', 355640), ('광운대 경원선', 334933), ('월계 경원선', 250821), ('녹천 경원선', 167134), ('창동 경원선', 7), ('방학 경원선', 333820), ('도봉 경원선', 196546), ('도봉산 경원선', 188231), ('망월사 경원선', 293428), ('회룡 경원선', 423808), ('의정부 경원선', 875482), ('가능 경원선', 255967), ('녹양 경원선', 179185), ('양주 경원선', 317204), ('덕계 경원선', 120351), ('덕정 경원선', 248655), ('지행 경원선', 284323), ('동두천중앙 경원선', 108952), ('보산 경원선', 66476), ('동두천 경원선', 78447), ('소요산 경원선', 48596)])
# 1. 의정부 경원선(875482명)
# 2. 왕십리(성동구청) 경원선(726662명)
# 3. 청량리(서울시립대입구) 경원선(647646명)
# 이용객이 가장 적은 역 순위
# 1. 창동 경원선(7명)
# 2. 옥수 경원선(2274명)
# 3. 소요산 경원선(48596명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('산본 안산선', 717269), ('대야미 안산선', 204373), ('반월 안산선', 180432), ('상록수 안산선', 745196), ('한대앞 안산선', 429561), ('중앙 안산선', 906400), ('고잔 안산선', 404021), ('초지 안산선', 228658), ('안산 안산선', 559913), ('신길온천 안산선', 75144), ('정왕 안산선', 437260), ('오이도 안산선', 403965), ('수리산 안산선', 153854)])
# 1. 중앙 안산선(906400명)
# 2. 상록수 안산선(745196명)
# 3. 산본 안산선(717269명)
# 이용객이 가장 적은 역 순위
# 1. 신길온천 안산선(75144명)
# 2. 수리산 안산선(153854명)
# 3. 반월 안산선(180432명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('선바위 과천선', 351538), ('경마공원 과천선', 132845), ('대공원 과천선', 76566), ('과천 과천선', 238875), ('정부과천청사 과천선', 462112), ('인덕원 과천선', 1113800), ('평촌 과천선', 804855), ('범계 과천선', 1224584)])
# 1. 범계 과천선(1224584명)
# 2. 인덕원 과천선(1113800명)
# 3. 평촌 과천선(804855명)
# 이용객이 가장 적은 역 순위
# 1. 대공원 과천선(76566명)
# 2. 경마공원 과천선(132845명)
# 3. 과천 과천선(238875명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('선릉 분당선', 755007), ('한티 분당선', 660423), ('도곡 분당선', 282563), ('구룡 분당선', 82588), ('개포동 분당선', 157913), ('대모산입구 분당선', 172650), ('수서 분당선', 650061), ('복정 분당선', 16), ('수원 분당선', 379548), ('서울숲 분당선', 516457), ('압구정로데오 분당선', 1063864), ('강남구청 분당선', 498349), ('선정릉 분당선', 368999), ('가천대 분당선', 403639), ('태평 분당선', 567604), ('모란 분당선', 839260), ('야탑 분당선', 1172350), ('서현 분당선', 1188827), ('수내 분당선', 579640), ('정자 분당선', 820506), ('미금 분당선', 668951), ('오리 분당선', 465599), ('이매 분당선', 236092), ('보정 분당선', 92403), ('죽전 분당선', 655422), ('구성 분당선', 214842), ('신갈 분당선', 192236), ('기흥 분당선', 441230), ('상갈 분당선', 230937), ('청명 분당선', 191245), ('영통 분당선', 421138), ('망포 분당선', 692460), ('매탄권선 분당선', 235520), ('수원시청 분당선', 673390), ('매교 분당선', 130301)])
# 1. 서현 분당선(1188827명)
# 2. 야탑 분당선(1172350명)
# 3. 압구정로데오 분당선(1063864명)
# 이용객이 가장 적은 역 순위
# 1. 복정 분당선(16명)
# 2. 구룡 분당선(82588명)
# 3. 보정 분당선(92403명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('원흥 일산선', 457507), ('지축 일산선', 11), ('삼송 일산선', 857608), ('원당 일산선', 448735), ('화정 일산선', 737720), ('대곡 일산선', 74943), ('백석 일산선', 420376), ('마두 일산선', 291713), ('정발산 일산선', 332036), ('주엽 일산선', 330383), ('대화 일산선', 502083)])
# 1. 삼송 일산선(857608명)
# 2. 화정 일산선(737720명)
# 3. 대화 일산선(502083명)
# 이용객이 가장 적은 역 순위
# 1. 지축 일산선(11명)
# 2. 대곡 일산선(74943명)
# 3. 마두 일산선(291713명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('회기 중앙선', 1096083), ('중랑 중앙선', 213858), ('상봉(시외버스터미널) 중앙선', 253282), ('망우 중앙선', 297525), ('양원 중앙선', 79418), ('구리 중앙선', 596807), ('도농 중앙선', 431166), ('양정 중앙선', 24580), ('덕소 중앙선', 224781), ('도심 중앙선', 83926), ('팔당 중앙선', 39315), ('운길산 중앙선', 23250), ('양수 중앙선', 63299), ('신원 중앙선', 5281), ('국수 중앙선', 23103), ('아신 중앙선', 19431), ('오빈 중앙선', 9250), ('양평 중앙선', 102469), ('원덕 중앙선', 9011), ('용문 중앙선', 51046), ('지평 중앙선', 1952)])
# 1. 회기 중앙선(1096083명)
# 2. 구리 중앙선(596807명)
# 3. 도농 중앙선(431166명)
# 이용객이 가장 적은 역 순위
# 1. 지평 중앙선(1952명)
# 2. 신원 중앙선(5281명)
# 3. 원덕 중앙선(9011명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('봉명 장항선', 43244), ('쌍용(나사렛대) 장항선', 90990), ('아산 장항선', 154788), ('탕정 장항선', 16682), ('배방 장항선', 44912), ('온양온천 장항선', 132802), ('신창(순천향대) 장항선', 73803)])
# 1. 아산 장항선(154788명)
# 2. 온양온천 장항선(132802명)
# 3. 쌍용(나사렛대) 장항선(90990명)
# 이용객이 가장 적은 역 순위
# 1. 탕정 장항선(16682명)
# 2. 봉명 장항선(43244명)
# 3. 배방 장항선(44912명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('서울역 경의선', 204726), ('신촌 경의선', 40149), ('효창공원앞 경의선', 139554), ('공덕 경의선', 157058), ('서강대 경의선', 95079), ('홍대입구 경의선', 99352), ('가좌 경의선', 205072), ('디지털미디어시티 경의선', 110650), ('수색 경의선', 116281), ('화전 경의선', 80084), ('강매 경의선', 127357), ('행신 경의선', 365811), ('능곡 경의선', 148444), ('곡산 경의선', 22791), ('백마 경의선', 299405), ('풍산 경의선', 236261), ('일산 경의선', 395859), ('탄현 경의선', 342604), ('야당 경의선', 336269), ('운정 경의선', 301654), ('금릉 경의선', 214948), ('금촌 경의선', 276367), ('월롱 경의선', 116713), ('파주 경의선', 49715), ('문산 경의선', 209648), ('임진강 경의선', 641), ('계양 경의선', 8), ('검암 경의선', 2)])
# 1. 일산 경의선(395859명)
# 2. 행신 경의선(365811명)
# 3. 탄현 경의선(342604명)
# 이용객이 가장 적은 역 순위
# 1. 검암 경의선(2명)
# 2. 계양 경의선(8명)
# 3. 임진강 경의선(641명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('신내 경춘선', 78278), ('갈매 경춘선', 118953), ('별내 경춘선', 138023), ('퇴계원 경춘선', 138549), ('사릉 경춘선', 140034), ('금곡 경춘선', 51435), ('평내호평 경춘선', 249632), ('천마산 경춘선', 55064), ('마석 경춘선', 151332), ('대성리 경춘선', 16348), ('청평 경춘선', 58421), ('상천 경춘선', 6425), ('가평 경춘선', 65662), ('굴봉산 경춘선', 4387), ('백양리 경춘선', 10210), ('강촌 경춘선', 16496), ('김유정 경춘선', 13032), ('남춘천 경춘선', 100682), ('춘천 경춘선', 52044)])
# 1. 평내호평 경춘선(249632명)
# 2. 마석 경춘선(151332명)
# 3. 사릉 경춘선(140034명)
# 이용객이 가장 적은 역 순위
# 1. 굴봉산 경춘선(4387명)
# 2. 상천 경춘선(6425명)
# 3. 백양리 경춘선(10210명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('고색 수인선', 205489), ('오목천 수인선', 138708), ('어천 수인선', 32842), ('야목 수인선', 12157), ('사리 수인선', 202585), ('달월 수인선', 3056), ('월곶 수인선', 113205), ('소래포구 수인선', 191701), ('인천논현 수인선', 250481), ('호구포 수인선', 180119), ('남동인더스파크 수인선', 105840), ('원인재 수인선', 196359), ('연수 수인선', 200507), ('송도 수인선', 96499), ('인하대 수인선', 266939), ('숭의 수인선', 156542), ('신포 수인선', 74811), ('인천 수인선', 50031)])
# 1. 인하대 수인선(266939명)
# 2. 인천논현 수인선(250481명)
# 3. 고색 수인선(205489명)
# 이용객이 가장 적은 역 순위
# 1. 달월 수인선(3056명)
# 2. 야목 수인선(12157명)
# 3. 어천 수인선(32842명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('판교 경강선', 230537), ('이매 경강선', 45319), ('삼동 경강선', 99738), ('경기광주 경강선', 345433), ('초월 경강선', 140668), ('곤지암 경강선', 101531), ('신둔도예촌 경강선', 63829), ('이천 경강선', 131518), ('부발 경강선', 101481), ('세종대왕릉 경강선', 11699), ('여주 경강선', 98126)])
# 1. 경기광주 경강선(345433명)
# 2. 판교 경강선(230537명)
# 3. 초월 경강선(140668명)
# 이용객이 가장 적은 역 순위
# 1. 세종대왕릉 경강선(11699명)
# 2. 이매 경강선(45319명)
# 3. 신둔도예촌 경강선(63829명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('방화 5호선', 269568), ('개화산 5호선', 223531), ('김포공항 5호선', 370098), ('송정 5호선', 263867), ('마곡 5호선', 478473), ('발산 5호선', 930624), ('우장산 5호선', 605041), ('화곡 5호선', 1231531), ('까치산 5호선', 1266153), ('신정(은행정) 5호선', 565458), ('목동 5호선', 773515), ('오목교(목동운동장앞) 5호선', 1075652), ('양평 5호선', 337641), ('영등포구청 5호선', 164608), ('영등포시장 5호선', 438434), ('신길 5호선', 206284), ('여의도 5호선', 1370522), ('여의나루 5호선', 438422), ('마포 5호선', 646827), ('공덕 5호선', 662026), ('애오개 5호선', 289460), ('충정로(경기대입구) 5호선', 218864), ('서대문 5호선', 829310), ('광화문(세종문화회관) 5호선', 1457734), ('종로3가 5호선', 520140), ('을지로4가 5호선', 232930), ('동대문역사문화공원(DDP) 5호선', 142743), ('청구 5호선', 163015), ('신금호 5호선', 281547), ('행당 5호선', 326641), ('왕십리(성동구청) 5호선', 232976), ('마장 5호선', 229251), ('답십리 5호선', 686095), ('장한평 5호선', 823426), ('군자(능동) 5호선', 571138), ('아차산(어린이대공원후문) 5호선', 621652), ('광나루(장신대) 5호선', 570429), ('천호(풍납토성) 5호선', 799047), ('강동 5호선', 796351), ('길동 5호선', 320754), ('굽은다리(강동구민회관앞) 5호선', 403436), ('명일 5호선', 354758), ('고덕 5호선', 397106), ('상일동 5호선', 632367), ('둔촌동 5호선', 358521), ('올림픽공원(한국체대) 5호선', 168681), ('방이 5호선', 309302), ('오금 5호선', 161608), ('개롱 5호선', 271358), ('거여 5호선', 377011), ('마천 5호선', 269137), ('강일 5호선', 154803), ('미사 5호선', 739769), ('하남풍산 5호선', 182947), ('하남시청(덕풍·신장) 5호선', 241325), ('하남검단산 5호선', 230654)])
# 1. 광화문(세종문화회관) 5호선(1457734명)
# 2. 여의도 5호선(1370522명)
# 3. 까치산 5호선(1266153명)
# 이용객이 가장 적은 역 순위
# 1. 동대문역사문화공원(DDP) 5호선(142743명)
# 2. 강일 5호선(154803명)
# 3. 오금 5호선(161608명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('응암 6호선', 748102), ('역촌 6호선', 173234), ('불광 6호선', 175144), ('독바위 6호선', 113466), ('연신내 6호선', 26), ('구산 6호선', 273861), ('새절(신사) 6호선', 514806), ('증산(명지대앞) 6호선', 420443), ('디지털미디어시티 6호선', 639578), ('월드컵경기장(성산) 6호선', 145506), ('마포구청 6호선', 607268), ('망원 6호선', 669681), ('합정 6호선', 657490), ('상수 6호선', 467524), ('광흥창(서강) 6호선', 387342), ('대흥(서강대앞) 6호선', 352489), ('공덕 6호선', 811932), ('효창공원앞 6호선', 288497), ('삼각지 6호선', 288139), ('녹사평(용산구청) 6호선', 242380), ('이태원 6호선', 538172), ('한강진 6호선', 507130), ('버티고개 6호선', 83177), ('약수 6호선', 154140), ('청구 6호선', 166577), ('신당 6호선', 410472), ('동묘앞 6호선', 328135), ('창신 6호선', 139858), ('보문 6호선', 326675), ('안암(고대병원앞) 6호선', 490838), ('고려대(종암) 6호선', 349810), ('월곡(동덕여대) 6호선', 486182), ('상월곡(한국과학기술연구원) 6호선', 245920), ('돌곶이 6호선', 382916), ('석계 6호선', 539265), ('태릉입구 6호선', 254030), ('화랑대(서울여대입구) 6호선', 473154), ('봉화산(서울의료원) 6호선', 369368), ('신내 6호선', 7)])
# 1. 공덕 6호선(811932명)
# 2. 응암 6호선(748102명)
# 3. 망원 6호선(669681명)
# 이용객이 가장 적은 역 순위
# 1. 신내 6호선(7명)
# 2. 연신내 6호선(26명)
# 3. 버티고개 6호선(83177명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('장암 7호선', 72835), ('도봉산 7호선', 438651), ('수락산 7호선', 516828), ('마들 7호선', 525969), ('노원 7호선', 889857), ('중계 7호선', 575832), ('하계 7호선', 747072), ('공릉(서울과학기술대) 7호선', 523675), ('태릉입구 7호선', 368144), ('먹골 7호선', 435667), ('중화 7호선', 469995), ('상봉(시외버스터미널) 7호선', 780818), ('면목 7호선', 687409), ('사가정 7호선', 702559), ('용마산(용마폭포공원) 7호선', 260145), ('중곡 7호선', 461767), ('군자(능동) 7호선', 605388), ('어린이대공원(세종대) 7호선', 584985), ('건대입구 7호선', 615992), ('뚝섬유원지 7호선', 321156), ('청담 7호선', 934833), ('강남구청 7호선', 815001), ('학동 7호선', 1173816), ('논현 7호선', 1003740), ('반포 7호선', 253209), ('고속터미널 7호선', 686317), ('내방 7호선', 640621), ('이수 7호선', 707470), ('남성 7호선', 458293), ('숭실대입구(살피재) 7호선', 561470), ('상도 7호선', 453684), ('장승배기 7호선', 384538), ('신대방삼거리 7호선', 709665), ('보라매 7호선', 444497), ('신풍 7호선', 486783), ('대림(구로구청) 7호선', 390385), ('남구로 7호선', 746310), ('가산디지털단지 7호선', 2115062), ('철산 7호선', 983593), ('광명사거리 7호선', 951446), ('천왕 7호선', 496416), ('온수(성공회대입구) 7호선', 462843), ('까치울 7호선', 354268), ('부천종합운동장 7호선', 216132), ('춘의 7호선', 459757), ('신중동 7호선', 676835), ('부천시청 7호선', 612058), ('상동 7호선', 654675), ('삼산체육관 7호선', 233479), ('굴포천 7호선', 448610), ('부평구청 7호선', 332406)])
# 1. 가산디지털단지 7호선(2115062명)
# 2. 학동 7호선(1173816명)
# 3. 논현 7호선(1003740명)
# 이용객이 가장 적은 역 순위
# 1. 장암 7호선(72835명)
# 2. 부천종합운동장 7호선(216132명)
# 3. 삼산체육관 7호선(233479명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('암사 8호선', 774610), ('천호(풍납토성) 8호선', 759894), ('강동구청 8호선', 457369), ('몽촌토성(평화의문) 8호선', 282441), ('잠실(송파구청) 8호선', 791757), ('석촌 8호선', 374090), ('송파 8호선', 316650), ('가락시장 8호선', 329508), ('문정 8호선', 1025750), ('장지 8호선', 793682), ('복정 8호선', 453037), ('산성 8호선', 245347), ('남한산성입구(성남법원.검찰청) 8호선', 575751), ('단대오거리 8호선', 436167), ('신흥 8호선', 183419), ('수진 8호선', 203744), ('모란 8호선', 146226), ('남위례 8호선', 70871)])
# 1. 문정 8호선(1025750명)
# 2. 장지 8호선(793682명)
# 3. 잠실(송파구청) 8호선(791757명)
# 이용객이 가장 적은 역 순위
# 1. 남위례 8호선(70871명)
# 2. 모란 8호선(146226명)
# 3. 신흥 8호선(183419명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('개화 9호선', 92750), ('김포공항 9호선', 538129), ('공항시장 9호선', 124711), ('신방화 9호선', 288056), ('마곡나루(서울식물원) 9호선', 564954), ('양천향교 9호선', 434776), ('가양 9호선', 854724), ('증미 9호선', 309022), ('등촌 9호선', 471159), ('염창 9호선', 782850), ('신목동 9호선', 163868), ('선유도 9호선', 385746), ('당산 9호선', 858210), ('국회의사당 9호선', 725315), ('여의도 9호선', 1266009), ('샛강 9호선', 257185), ('노량진 9호선', 1253074), ('노들 9호선', 170434), ('흑석(중앙대입구) 9호선', 334682), ('동작(현충원) 9호선', 70613), ('구반포 9호선', 62794), ('신반포 9호선', 140450), ('고속터미널 9호선', 697159), ('사평 9호선', 149148), ('신논현 9호선', 1631749)])
# 1. 신논현 9호선(1631749명)
# 2. 여의도 9호선(1266009명)
# 3. 노량진 9호선(1253074명)
# 이용객이 가장 적은 역 순위
# 1. 구반포 9호선(62794명)
# 2. 동작(현충원) 9호선(70613명)
# 3. 개화 9호선(92750명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('서울역 공항철도 1호선', 392036), ('공덕 공항철도 1호선', 128151), ('홍대입구 공항철도 1호선', 549294), ('디지털미디어시티 공항철도 1호선', 615381), ('마곡나루(서울식물원) 공항철도 1호선', 377031), ('김포공항 공항철도 1호선', 513926), ('계양 공항철도 1호선', 476130), ('검암 공항철도 1호선', 329175), ('청라국제도시 공항철도 1호선', 325603), ('운서 공항철도 1호선', 329243), ('공항화물청사 공항철도 1호선', 110491), ('인천공항1터미널 공항철도 1호선', 205441), ('인천공항2터미널 공항철도 1호선', 113363), ('영종 공항철도 1호선', 135482)])
# 1. 디지털미디어시티 공항철도 1호선(615381명)
# 2. 홍대입구 공항철도 1호선(549294명)
# 3. 김포공항 공항철도 1호선(513926명)
# 이용객이 가장 적은 역 순위
# 1. 공항화물청사 공항철도 1호선(110491명)
# 2. 인천공항2터미널 공항철도 1호선(113363명)
# 3. 공덕 공항철도 1호선(128151명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('언주 9호선2~3단계', 516659), ('선정릉 9호선2~3단계', 470303), ('삼성중앙 9호선2~3단계', 311704), ('봉은사 9호선2~3단계', 855843), ('종합운동장 9호선2~3단계', 190868), ('삼전 9호선2~3단계', 306658), ('석촌고분 9호선2~3단계', 271811), ('석촌 9호선2~3단계', 374050), ('송파나루 9호선2~3단계', 246790), ('한성백제 9호선2~3단계', 105241), ('올림픽공원(한국체대) 9호선2~3단계', 343184), ('둔촌오륜 9호선2~3단계', 49060), ('중앙보훈병원 9호선2~3단계', 364749)])
# 1. 봉은사 9호선2~3단계(855843명)
# 2. 언주 9호선2~3단계(516659명)
# 3. 선정릉 9호선2~3단계(470303명)
# 이용객이 가장 적은 역 순위
# 1. 둔촌오륜 9호선2~3단계(49060명)
# 2. 한성백제 9호선2~3단계(105241명)
# 3. 종합운동장 9호선2~3단계(190868명)
#
# 이용객이 가장 많은 역 순위
# dict_items([('북한산우이 우이신설선', 90155), ('솔밭공원 우이신설선', 78215), ('4.19민주묘지 우이신설선', 92853), ('가오리 우이신설선', 136189), ('화계 우이신설선', 105656), ('삼양 우이신설선', 62905), ('삼양사거리 우이신설선', 70717), ('솔샘 우이신설선', 229243), ('북한산보국문 우이신설선', 241088), ('정릉 우이신설선', 162171), ('성신여대입구(돈암) 우이신설선', 143258), ('보문 우이신설선', 56376), ('신설동 우이신설선', 66800)])
# 1. 북한산보국문 우이신설선(241088명)
# 2. 솔샘 우이신설선(229243명)
# 3. 정릉 우이신설선(162171명)
# 이용객이 가장 적은 역 순위
# 1. 보문 우이신설선(56376명)
# 2. 삼양 우이신설선(62905명)
# 3. 신설동 우이신설선(66800명)
